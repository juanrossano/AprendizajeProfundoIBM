# %% [markdown]
# Este proyecto final de IA es una experiencia práctica y apasionante en el aprendizaje profundo aplicado a la clasificación de imágenes, específicamente a imágenes satelitales. Imagina que eres un científico de datos en una empresa de fertilizantes y quieres expandirte a nuevos mercados. El proyecto te permite crear modelos de IA que clasifican automáticamente las imágenes en terrenos agrícolas y no agrícolas, ahorrando tiempo y esfuerzo en comparación con la clasificación manual y ayudando a la empresa a desarrollar su estrategia de manera eficiente.

# %% [markdown]
# En este curso, los laboratorios se estructuraron en cuatro módulos, comenzando con el manejo básico de datos y avanzando hacia redes neuronales sofisticadas. Se trabajó con un conjunto de datos de imágenes satelitales almacenadas en carpetas: una para "class_0_non_agri" (terrenos no agrícolas) y otra para "class_1_agri" (terrenos agrícolas). El objetivo era la clasificación binaria, es decir, determinar si una imagen mostraba terrenos agrícolas o no agrícolas. Se utilizaron cuadernos Jupyter, lo que permitió la interactividad, la ejecución de código, la visualización de imágenes, el entrenamiento y la evaluación de modelos.

# %% [markdown]
# El aprendizaje profundo es como enseñar a una computadora a reconocer patrones mediante capas de "neuronas" inspiradas en las matemáticas. Analizaste las comparaciones entre frameworks como Keras (fácil de usar y de alto nivel) y PyTorch (más flexible y de bajo nivel). Al final, integraste modelos y los evaluaste, adquiriendo habilidades aplicables a problemas del mundo real, como el monitoreo climático o la planificación urbana.
#
# Repasemos lo que hiciste en todos los módulos.

# %% [markdown]
# ## Módulo 1: Preparación y exploración de datos
#
# La base de cualquier proyecto de IA son los datos, y el Módulo 1 se centró en la carga y exploración eficiente de imágenes satelitales. Piensa en los datos como el combustible de tu motor de IA; si están desorganizados, tu modelo no tendrá un buen rendimiento. Los laboratorios hicieron hincapié en la eficiencia de la memoria, utilizando la carga diferida de imágenes, una por una, en lugar de todas a la vez, para evitar que el ordenador se bloquee. Exploraste las ventajas y desventajas de la carga masiva, donde leías todas las imágenes en una lista de matrices (usando NumPy) para un acceso más rápido, pero con un mayor consumo de memoria.
#
# Al finalizar este módulo, preparaste conjuntos de datos equilibrados (con la misma cantidad de muestras agrícolas y no agrícolas) y aprendiste los fundamentos del preprocesamiento, como redimensionar imágenes a un tamaño estándar (por ejemplo, 64x64 píxeles) y aplicar técnicas de aumento para incrementar el conjunto de datos de entrenamiento del modelo.

# %% [markdown]
# ## Módulo 2: Construcción y comparación de clasificadores básicos
#
# A continuación, creaste clasificadores utilizando redes neuronales convolucionales (CNN), las herramientas fundamentales de la IA de imágenes.
#
# Primero, construiste una CNN simple en Keras (basado en TensorFlow). Keras es fácil de usar para principiantes y cuenta con comandos de alto nivel. Definiste capas: las capas convolucionales extraen características como bordes o colores, las capas de agrupación reducen el tamaño y las capas densas toman decisiones.
#
# La compilaste con un optimizador (como Adam) y una función de pérdida (entropía cruzada binaria), y luego la entrenaste con tus rutas de imágenes, dividiendo los datos en conjuntos de entrenamiento y prueba (por ejemplo, 80/20). La evaluación utiliza métricas como la precisión, que mide con qué frecuencia el modelo clasifica correctamente los datos agrícolas frente a los no agrícolas.
#
# Después, usaste PyTorch, que ofrece mayor control. Definiste una clase que hereda de nn.Module, con un método forward para el flujo de datos. Es como construir con bloques de Lego.

# %%
import torch.nn as nn

class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, 3)
        self.pool = nn.MaxPool2d(2,2)
        self.fc = nn.Linear(..., 1)  # Adjust based on shape

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = x.flatten()
        return torch.sigmoid(self.fc(x))

# %% [markdown]
# El entrenamiento incluyó cargadores de datos (usando torch.utils.data.DataLoader) para procesar imágenes por lotes y un bucle con pasos de optimización. PyTorch fue más práctico, permitiendo ajustes personalizados.
#
# En el laboratorio de análisis comparativo, se compararon ambos modelos con los mismos datos. Si bien Keras podría entrenar más rápido, PyTorch destaca en la depuración. La evaluación se realizó con matrices de confusión (que muestran verdaderos positivos y falsos negativos) y métricas como precisión/exhaustividad. Los resultados mostraron una precisión superior al 95%, dependiendo de la calidad de los datos. Lección clave: No existe un único framework que sea el mejor; la elección depende del nivel de experiencia y las necesidades.

# %% [markdown]
# ## Module 3: Advanced models with Vision Transformers (ViTs)
#
# Luego, te presentaron los Vision Transformers (ViTs), una alternativa de vanguardia a las CNN inspirada en modelos de lenguaje como GPT.
#
# Los ViTs procesan las imágenes como secuencias de parches (como dividir una foto en mosaicos) y luego utilizan la autoatención para enfocarse en las partes importantes. Para principiantes, la atención es como el modelo que "presta atención" a las zonas verdes en terrenos agrícolas. En Keras, usaste capas o bibliotecas predefinidas como tensorflow_addons y creaste:

# %%
from tensorflow.keras import layers
layers.LayerNormalization
layers.MultiHeadAttention

# %% [markdown]
# Diseñaste y entrenaste los modelos híbridos CNN-ViT para el conjunto de datos satelitales, utilizando el aprendizaje por transferencia de un modelo CNN preentrenado para ahorrar tiempo y recursos computacionales. El entrenamiento implicó el manejo de secuencias, que requerían mucha memoria, por lo que se mantuvieron lotes pequeños. El híbrido CNN-ViT combina las ventajas de las CNN y los ViT. Las CNN destacan en la extracción de características locales, y los ViT analizan las correlaciones globales de manera eficiente. La combinación de estas dos características en un único modelo híbrido CNN-ViT te brindó lo mejor de ambos mundos y creó un modelo capaz de proporcionar predicciones muy precisas.
#
# Los ViT suelen tener un mejor rendimiento en patrones complejos (por ejemplo, al distinguir vegetación sutil), pero requieren más datos y capacidad de procesamiento. La precisión puede alcanzar más del 90 %, lo que explica por qué los ViT impulsan la IA moderna, como DALL-E.

# %% [markdown]
# ## Módulo 4: Integración y evaluación final
#
# El proyecto final concluye con la evaluación de los modelos híbridos CNN-ViT. La evaluación incluye validación cruzada y pruebas en entornos reales, y aborda el sobreajuste (el modelo memoriza los datos de entrenamiento) y soluciones como el abandono (dropout).

# %% [markdown]
# ## Conclusión del proyecto y principales lecciones aprendidas
#
# Este proyecto te transformó de principiante en la carga de imágenes a experto en la creación de clasificadores de IA. Clasificaste tipos de terreno con una precisión superior al 95 %, aprendiste Keras por su simplicidad y PyTorch por su flexibilidad, y exploraste ViTs para tareas avanzadas. Sus aplicaciones abarcan desde la expansión territorial en una empresa de fertilizantes hasta la respuesta ante desastres o la tecnología agrícola. Desafíos como el desequilibrio de datos te enseñan habilidades reales de IA. En definitiva, es un proyecto final gratificante que demuestra el poder del aprendizaje profundo para resolver problemas industriales reales. Si te inspira, ¡intenta ampliarlo con tus propios conjuntos de datos!
